# %%
import os
import glob
import pandas as pd
import panel as pn
pn.extension('tabulator')
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

import hvplot.pandas
import hvplot.pandas
from bokeh.sampledata.penguins import data as df
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# #### In our dataset we have large number of files, first we going to merge all files together into a single DataFrame
# #### First we giving path where the dataset stored,
# #### then we using glob = Python glob. glob() method returns a list of files or folders that matches the path
# #### Specified in the pathname argument.
# #### Next ,Read the CSV file and stored it as a temporary dataframe
# #### Use Rindex to get last occurence of the '/' and ignore the file folder information
# #### Also split the data into city & Type like weekend, weekday
# #### Create city and type columns in the dataframe and store the values for future processing
# #### Append the temporary dataframe into an array of dataframes
# #### Append all the dataframes into single dataframe using concat function

# %%
#define path to CSV files
path = r'dataset'


#identify all CSV files
all_files = glob.glob(os.path.join(path,"*.csv"))

allFiles_df=[]

for files in all_files:
     
    temp = pd.read_csv(files , index_col=[0]);
    fileName = files[files.rindex('\\')+1:files.index('.')].split('_')
    
    temp['city']=fileName[0];
    temp['type']=fileName[1];
    
    allFiles_df.append(temp);
 

airbnb_df=pd.concat(allFiles_df, ignore_index=True)

# %% [markdown]
# #### Using head and tail functions to see first and last 5 rows

# %%
airbnb_df.head()
# Out:
#       realSum     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True              2.0
# 1  344.245776  Private room        False          True              4.0
# 2  264.101422  Private room        False          True              2.0
# 3  433.529398  Private room        False          True              4.0
# 4  485.552926  Private room        False          True              2.0
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      1    0                10.0
# 1              False      0    0                 8.0
# 2              False      0    1                 9.0
# 3              False      0    1                 9.0
# 4               True      0    0                10.0
#
#    guest_satisfaction_overall  ...      dist  metro_dist  attr_index  \
# 0                        93.0  ...  5.022964    2.539380   78.690379
# 1                        85.0  ...  0.488389    0.239404  631.176378
# 2                        87.0  ...  5.748312    3.651621   75.275877
# 3                        90.0  ...  0.384862    0.439876  493.272534
# 4                        98.0  ...  0.544738    0.318693  552.830324
#
#    attr_index_norm  rest_index  rest_index_norm      lng       lat       city  \
# 0         4.166708   98.253896         6.846473  4.90569  52.41772  amsterdam
# 1        33.421209  837.280757        58.342928  4.90005  52.37432  amsterdam
# 2         3.985908   95.386955         6.646700  4.97512  52.36103  amsterdam
# 3        26.119108  875.033098        60.973565  4.89417  52.37663  amsterdam
# 4        29.272733  815.305740        56.811677  4.90051  52.37508  amsterdam
#
#        type
# 0  weekdays
# 1  weekdays
# 2  weekdays
# 3  weekdays
# 4  weekdays
#
# [5 rows x 21 columns]

# %%
airbnb_df.tail()
# Out:
#           realSum        room_type  room_shared  room_private  \
# 51702  715.938574  Entire home/apt        False         False
# 51703  304.793960  Entire home/apt        False         False
# 51704  637.168969  Entire home/apt        False         False
# 51705  301.054157     Private room        False          True
# 51706  133.230489     Private room        False          True
#
#        person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 51702              6.0              False      0    1                10.0
# 51703              2.0              False      0    0                 8.0
# 51704              2.0              False      0    0                10.0
# 51705              2.0              False      0    0                10.0
# 51706              4.0               True      1    0                10.0
#
#        guest_satisfaction_overall  ...      dist  metro_dist  attr_index  \
# 51702                       100.0  ...  0.530181    0.135447  219.402478
# 51703                        86.0  ...  0.810205    0.100839  204.970121
# 51704                        93.0  ...  0.994051    0.202539  169.073402
# 51705                        87.0  ...  3.044100    0.287435  109.236574
# 51706                        93.0  ...  1.263932    0.480903  150.450381
#
#        attr_index_norm  rest_index  rest_index_norm       lng       lat  \
# 51702        15.712158  438.756874        10.604584  16.37940  48.21136
# 51703        14.678608  342.182813         8.270427  16.38070  48.20296
# 51704        12.107921  282.296425         6.822996  16.38568  48.20460
# 51705         7.822803  158.563398         3.832416  16.34100  48.19200
# 51706        10.774264  225.247293         5.444140  16.39066  48.20811
#
#          city      type
# 51702  vienna  weekends
# 51703  vienna  weekends
# 51704  vienna  weekends
# 51705  vienna  weekends
# 51706  vienna  weekends
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Cleaning dataset
#
# #### checking is there any missing data or null values in our dataset,where in this data set we dont have any null rows
# ####  getting to know more about dataset, by knowing the total size of rows and columns ,maxium,min, price range for airbnb  stay,seeing difference between weekend and weekday stay,room availability,

# %%
airbnb_df.isnull().sum()
# Out:
# realSum                       0
# room_type                     0
# room_shared                   0
# room_private                  0
# person_capacity               0
# host_is_superhost             0
# multi                         0
# biz                           0
# cleanliness_rating            0
# guest_satisfaction_overall    0
# bedrooms                      0
# dist                          0
# metro_dist                    0
# attr_index                    0
# attr_index_norm               0
# rest_index                    0
# rest_index_norm               0
# lng                           0
# lat                           0
# city                          0
# type                          0
# dtype: int64

# %%
airbnb_df.shape
# Out:
# (51707, 21)

# %%
weekdays_df.shape
# Out:
# (25500, 9)

# %% [markdown]
# #### so below describe function show us the overall view of dataset The describe() method returns description of the data in the DataFrame.
# #### If the DataFrame contains numerical data, the description contains these information for each column:

# %%
airbnb_df.describe()
# Out:
#             realSum  person_capacity         multi           biz  \
# count  51707.000000     51707.000000  51707.000000  51707.000000
# mean     279.879591         3.161661      0.291353      0.350204
# std      327.948386         1.298545      0.454390      0.477038
# min       34.779339         2.000000      0.000000      0.000000
# 25%      148.752174         2.000000      0.000000      0.000000
# 50%      211.343089         3.000000      0.000000      0.000000
# 75%      319.694287         4.000000      1.000000      1.000000
# max    18545.450285         6.000000      1.000000      1.000000
#
#        cleanliness_rating  guest_satisfaction_overall     bedrooms  \
# count        51707.000000                51707.000000  51707.00000
# mean             9.390624                   92.628232      1.15876
# std              0.954868                    8.945531      0.62741
# min              2.000000                   20.000000      0.00000
# 25%              9.000000                   90.000000      1.00000
# 50%             10.000000                   95.000000      1.00000
# 75%             10.000000                   99.000000      1.00000
# max             10.000000                  100.000000     10.00000
#
#                dist    metro_dist    attr_index  attr_index_norm  \
# count  51707.000000  51707.000000  51707.000000     51707.000000
# mean       3.191285      0.681540    294.204105        13.423792
# std        2.393803      0.858023    224.754123         9.807985
# min        0.015045      0.002301     15.152201         0.926301
# 25%        1.453142      0.248480    136.797385         6.380926
# 50%        2.613538      0.413269    234.331748        11.468305
# 75%        4.263077      0.737840    385.756381        17.415082
# max       25.284557     14.273577   4513.563486       100.000000
#
#          rest_index  rest_index_norm           lng           lat
# count  51707.000000     51707.000000  51707.000000  51707.000000
# mean     626.856696        22.786177      7.426068     45.671128
# std      497.920226        17.804096      9.799725      5.249263
# min       19.576924         0.592757     -9.226340     37.953000
# 25%      250.854114         8.751480     -0.072500     41.399510
# 50%      522.052783        17.542238      4.873000     47.506690
# 75%      832.628988        32.964603     13.518825     51.471885
# max     6696.156772       100.000000     23.786020     52.641410

# %% [markdown]
# #### DROP column we no longer using

# %%
weekends_df = airbnb_df[(airbnb_df['type']=='weekends')]
weekends_df.head()
# Out:
#           realSum        room_type  room_shared  room_private  \
# 1103   319.640053     Private room        False          True
# 1104   347.995219     Private room        False          True
# 1105   482.975183     Private room        False          True
# 1106   485.552926     Private room        False          True
# 1107  2771.541724  Entire home/apt        False         False
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 1103              2.0              False      0    1                 9.0
# 1104              2.0              False      0    1                 9.0
# 1105              4.0              False      0    1                 9.0
# 1106              2.0               True      0    0                10.0
# 1107              4.0               True      0    0                10.0
#
#       guest_satisfaction_overall  ...      dist  metro_dist  attr_index  \
# 1103                        88.0  ...  4.763360    0.852117  110.906123
# 1104                        87.0  ...  5.748310    3.651591   75.275937
# 1105                        90.0  ...  0.384872    0.439852  493.272517
# 1106                        98.0  ...  0.544723    0.318688  552.849514
# 1107                       100.0  ...  1.686798    1.458399  208.809162
#
#       attr_index_norm  rest_index  rest_index_norm      lng       lat  \
# 1103         5.871971  136.982208        11.941560  4.84639  52.34137
# 1104         3.985516   95.386468         8.315410  4.97512  52.36103
# 1105        26.116521  875.114817        76.289005  4.89417  52.37663
# 1106        29.270850  815.303994        71.074937  4.90051  52.37508
# 1107        11.055489  272.315202        23.739349  4.88467  52.38749
#
#            city      type
# 1103  amsterdam  weekends
# 1104  amsterdam  weekends
# 1105  amsterdam  weekends
# 1106  amsterdam  weekends
# 1107  amsterdam  weekends
#
# [5 rows x 21 columns]

# %%
#drop_column= airbnb_df.drop(['room_shared','host_is_superhost','room_shared','room_private',"multi",'biz','attr_index','attr_index_norm','rest_index','rest_index_norm','lng','lat','type'], axis=1, inplace=False)
#drop_column

# %%
drop_column= airbnb_df.drop(['room_shared','host_is_superhost','room_shared','room_private',"multi",'biz','attr_index','attr_index_norm','rest_index','rest_index_norm','lng','lat','type'], axis=1, inplace=False)
drop_column
# Out:
#           realSum        room_type  person_capacity  cleanliness_rating  \
# 0      194.033698     Private room              2.0                10.0
# 1      344.245776     Private room              4.0                 8.0
# 2      264.101422     Private room              2.0                 9.0
# 3      433.529398     Private room              4.0                 9.0
# 4      485.552926     Private room              2.0                10.0
# ...           ...              ...              ...                 ...
# 51702  715.938574  Entire home/apt              6.0                10.0
# 51703  304.793960  Entire home/apt              2.0                 8.0
# 51704  637.168969  Entire home/apt              2.0                10.0
# 51705  301.054157     Private room              2.0                10.0
# 51706  133.230489     Private room              4.0                10.0
#
#        guest_satisfaction_overall  bedrooms      dist  metro_dist       city
# 0                            93.0         1  5.022964    2.539380  amsterdam
# 1                            85.0         1  0.488389    0.239404  amsterdam
# 2                            87.0         1  5.748312    3.651621  amsterdam
# 3                            90.0         2  0.384862    0.439876  amsterdam
# 4                            98.0         1  0.544738    0.318693  amsterdam
# ...                           ...       ...       ...         ...        ...
# 51702                       100.0         3  0.530181    0.135447     vienna
# 51703                        86.0         1  0.810205    0.100839     vienna
# 51704                        93.0         1  0.994051    0.202539     vienna
# 51705                        87.0         1  3.044100    0.287435     vienna
# 51706                        93.0         1  1.263932    0.480903     vienna
#
# [51707 rows x 9 columns]

# %%
weekdays_df = drop_column.loc[(airbnb_df['type']== "weekdays")]
weekdays_df
# Out:
#           realSum        room_type  person_capacity  cleanliness_rating  \
# 0      194.033698     Private room              2.0                10.0
# 1      344.245776     Private room              4.0                 8.0
# 2      264.101422     Private room              2.0                 9.0
# 3      433.529398     Private room              4.0                 9.0
# 4      485.552926     Private room              2.0                10.0
# ...           ...              ...              ...                 ...
# 49903  219.012224  Entire home/apt              4.0                 8.0
# 49904  191.197438  Entire home/apt              4.0                10.0
# 49905  251.501765  Entire home/apt              2.0                 8.0
# 49906  637.636444  Entire home/apt              2.0                10.0
# 49907  133.230489     Private room              4.0                10.0
#
#        guest_satisfaction_overall  bedrooms      dist  metro_dist       city
# 0                            93.0         1  5.022964    2.539380  amsterdam
# 1                            85.0         1  0.488389    0.239404  amsterdam
# 2                            87.0         1  5.748312    3.651621  amsterdam
# 3                            90.0         2  0.384862    0.439876  amsterdam
# 4                            98.0         1  0.544738    0.318693  amsterdam
# ...                           ...       ...       ...         ...        ...
# 49903                        80.0         0  0.298179    0.257904     vienna
# 49904                       100.0         2  1.052982    0.332054     vienna
# 49905                        86.0         1  0.810224    0.100844     vienna
# 49906                        93.0         1  0.994039    0.202537     vienna
# 49907                        93.0         1  1.263948    0.480922     vienna
#
# [25500 rows x 9 columns]

# %%
weekends_df = drop_column[(airbnb_df['type']=='weekends')]
weekends_df.head()
# Out:
#           realSum        room_type  person_capacity  cleanliness_rating  \
# 1103   319.640053     Private room              2.0                 9.0
# 1104   347.995219     Private room              2.0                 9.0
# 1105   482.975183     Private room              4.0                 9.0
# 1106   485.552926     Private room              2.0                10.0
# 1107  2771.541724  Entire home/apt              4.0                10.0
#
#       guest_satisfaction_overall  bedrooms      dist  metro_dist       city
# 1103                        88.0         1  4.763360    0.852117  amsterdam
# 1104                        87.0         1  5.748310    3.651591  amsterdam
# 1105                        90.0         2  0.384872    0.439852  amsterdam
# 1106                        98.0         1  0.544723    0.318688  amsterdam
# 1107                       100.0         3  1.686798    1.458399  amsterdam

# %% [markdown]
# ### we have 10 unique city display in airbnb and mostly the differnce between  rooms listings in weekends and weekday are almost same.where in entire home/apt type listings in weekends are litlle higher

# %%
city_list =airbnb_df.city.unique()
print(city_list)
# Out:
# ['amsterdam' 'athens' 'barcelona' 'berlin' 'budapest' 'lisbon' 'london'
#  'paris' 'rome' 'vienna']

# %%
df = airbnb_df.groupby(['type','room_type']).size()
df
# Out:
# type      room_type
# weekdays  Entire home/apt    15994
#           Private room        9326
#           Shared room          180
# weekends  Entire home/apt    16654
#           Private room        9367
#           Shared room          186
# dtype: int64

# %%
#weekends_df.city.value_counts()

# %% [markdown]
# ### Here it show max amd min rate for rooms, where as london and rome has more airbnb listings ,amsterdam has less airbnb service

# %%
weekdays_df.realSum.max()
# Out:
# 18545.450284723363

# %%
weekends_df.realSum.max()
# Out:
# 13656.35883

# %%
weekends_df.realSum.min()
# Out:
# 34.77933919255534

# %%
weekdays_df.realSum.min()
# Out:
# 37.12929454340368

# %%
availability = airbnb_df.groupby(['city','type']).size()
availability
# Out:
# city       type
# amsterdam  weekdays    1103
#            weekends     977
# athens     weekdays    2653
#            weekends    2627
# barcelona  weekdays    1555
#            weekends    1278
# berlin     weekdays    1284
#            weekends    1200
# budapest   weekdays    2074
#            weekends    1948
# lisbon     weekdays    2857
#            weekends    2906
# london     weekdays    4614
#            weekends    5379
# paris      weekdays    3130
#            weekends    3558
# rome       weekdays    4492
#            weekends    4535
# vienna     weekdays    1738
#            weekends    1799
# dtype: int64

# %% [markdown]
# ### shows the relationship between a numeric and a categoric variable.

# %%
#availability.plot.bar( x = 'city',hue = "type")

#sns.barplot(x=city,y = 'type',hue='type',df = availability,)

#availability.plot(kind="bar")
#plt.title("Available airbnb listings")
#plt.xlabel("city")
#plt.ylabel("type")

s = availability.plot(kind='bar', color=[ "PINK",'ORANGE'])


s.set_title('Europe room listings')
# Out:
# Text(0.5, 1.0, 'Europe room listings')

# %% [markdown]
# ### Here we using interactive dataframe to createa dashboard in python and creating a pipeline btween to connect

# %%
# make dataframe pipeline interactive
idf = weekends_df.interactive()

# %%
rate_silder = pn.widgets.FloatSlider(name ='price', start=34.77, end =20000, step = 5, width=200)
select_city = pn.widgets.Select(name='Select_city', options=['amsterdam' ,'athens' ,'barcelona' ,'berlin' ,'budapest', 'lisbon', 'london', 'paris', 'rome', 'vienna'], width=200)
select_bedroom = pn.widgets.Select(name ='bedroom_type',options =[1,2,3,4])
select_room_type = pn.widgets.Select(name ='room_type',options =['Entire home/apt' ,'Private room', 'Shared room'])

pn.Row(rate_silder,select_city,select_bedroom,select_room_type)
#pn.Row(Rental_pipeline, width=800)
# Out:
# Row
#     [0] FloatSlider(end=20000, name='price', start=34.77, step=5, value=34.77, width=200)
#     [1] Select(options=['amsterdam', ...], value='amsterdam', width=200)
#     [2] Select(name='bedroom_type', options=[1, 2, 3, 4], value=1)
#     [3] Select(name='room_type', options=['Entire home/apt', ...], value='Entire home/apt')

# %%
Rental_pipeline=idf[ (idf.realSum >= rate_silder) & (idf.city == select_city)&(idf.room_type ==select_room_type) &(idf.bedrooms==select_bedroom)]

# %%
RentalTable=Rental_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width') #

# %%
RentalTable
# Out:
# <div id='1009'>
#   <div class="bk-root" id="5da6e923-b570-4570-8afa-f2773fe87093" data-root-id="1009"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"6f4535d2-b9f5-467c-87b9-1fa20c069a19":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"editor":{"id":"1058"},"field":"dist","formatter":{"id":"1057"},"title":"dist","width":0},"id":"1059","type":"TableColumn"},{"attributes":{"editor":{"id":"1053"},"field":"bedrooms","formatter":{"id":"1052"},"title":"bedrooms","width":0},"id":"1054","type":"TableColumn"},{"attributes":{"children":[{"id":"1011"},{"id":"1018"}],"margin":[0,0,0,0],"name":"Column01300"},"id":"1010","type":"Column"},{"attributes":{"columns":[{"id":"1024"},{"id":"1029"},{"id":"1034"},{"id":"1039"},{"id":"1044"},{"id":"1049"},{"id":"1054"},{"id":"1059"},{"id":"1064"},{"id":"1069"}],"configuration":{"columns":[{"field":"index"},{"field":"realSum"},{"field":"room_type"},{"field":"person_capacity"},{"field":"cleanliness_rating"},{"field":"guest_satisfaction_overall"},{"field":"bedrooms"},{"field":"dist"},{"field":"metro_dist"},{"field":"city"}],"dataTree":false,"selectable":true},"indexes":["index"],"layout":"fit_data_table","margin":[5,10,5,10],"max_page":32,"name":"","page":1,"page_size":10,"pagination":"remote","select_mode":true,"selectable_rows":null,"sizing_mode":"stretch_width","source":{"id":"1019"},"styles":{"data":{},"id":"5307898813bb46b09a6aaf40436c069f"},"subscribed_events":["table-edit","cell-click"]},"id":"1072","type":"panel.models.tabulator.DataTabulator"},{"attributes":{"children":[{"id":"1012"},{"id":"1017"}],"margin":[0,0,0,0],"name":"Row01299"},"id":"1011","type":"Row"},{"attributes":{"children":[{"id":"1010"}] ...

# %%
# Defining colors for the pie chart
colors = ['pink', 'silver', 'steelblue']
  
# Plotting the pie chart for above dataframe

Rooms = idf[(idf.city == select_city)].groupby(['room_type']).sum().plot(
    kind='pie',y ='bedrooms',  
  autopct='%1.0f%%', colors=colors)
Rooms
# Out:
# <div id='1091'>
#   <div class="bk-root" id="4b89fe3f-1576-402d-b651-d35d37efdef6" data-root-id="1091"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"ce2c41dc-5bb4-4a00-82cd-43ef9afe7301":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"margin":[5,10,5,10],"min_width":200,"options":["amsterdam","athens","barcelona","berlin","budapest","lisbon","london","paris","rome","vienna"],"title":"Select_city","value":"amsterdam","width":200},"id":"1095","type":"panel.models.widgets.CustomSelect"},{"attributes":{"children":[{"id":"1092"}],"margin":[0,0,0,0],"name":"Row01588"},"id":"1091","type":"Row"},{"attributes":{"height":480,"margin":[5,5,5,5],"name":"ParamFunction01559","text":"&lt;img src=&quot;data:image/png;base64,...&quot; width=&quot;640px&quot; height=&quot;480px&quot; alt=&quot;&quot;&gt;&lt;/img&gt;","width":640},"id":"1098","type":"panel.models.markup.HTML"},{"attributes":{"children":[{"id":"1095"}],"margin":[0,0,0,0],"name":"Column01558"},"id":"1094","type":"Column"},{"attributes":{"children":[{"id":"1093"},{"id":"1097"}],"margin":[0,0,0,0],"name":"Column01587"},"id":"1092","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer01585","sizing_mode":"stretch_width"},"id":"1096","type":"Spacer"},{"attributes":{"children":[{"id":"1098"}],"margin":[0,0,0,0],"name":"Row01563"},"id":"1097","type":"Row"},{"attributes":{"client_comm_id":"3185e17926234bb59daee27de9d0cc73","comm_id":"962cb4ee7135456fbd47a1596a7cbffa","plot_id":"1091"},"id":"1099","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"1094"},{"id":"1096"}],"margin":[0,0,0,0],"name":"Row01586"},"id":"1093","type":"Row"}],"root_ids":["1091", ...
#     var render_items = [{"docid":"ce2c41dc-5bb4-4a00-82cd-43ef9afe7301","root_ids":["1091"],"roots":{"1091":"4b89fe3f-1576-402d-b651-d35d37efdef6"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
bedrooms_bar = idf[(idf.city == select_city)].groupby(['bedrooms']).size().plot(
    kind='bar',  color='ORANGE', xlabel='Bedrooms', ylabel='Count', title='Bedrooms Distribution')
bedrooms_bar
# Out:
# <div id='1100'>
#   <div class="bk-root" id="22c7dbfd-250f-487e-91be-cf56d4e01ad5" data-root-id="1100"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"eca5a74f-ad83-4429-9799-7cd38f379ca8":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"GridStack1","overrides":[],"properties":[{"default":"warn","kind":null,"name":"mode"},{"default":null,"kind":null,"name":"ncols"},{"default":null,"kind":null,"name":"nrows"},{"default":true,"kind":null,"name":"allow_resize"},{"default":true,"kind":null,"name":"allow_drag"},{"default":[],"kind":null,"name":"state"}]},{"extends":null,"module":null,"name":"click1","overrides":[],"properties":[{"default":"","kind":null,"name":"terminal_output"},{"default":"","kind":null,"name":"debug_name"},{"default":0,"kind":null,"name":"clears"}]},{"extends":null,"module":null,"name":"NotificationAreaBase1","overrides":[],"properties":[{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"}]},{"extends":null,"module":null,"name":"NotificationArea1","overrides":[],"properties":[{"default":[],"kind":null,"name":"notifications"},{"default":"bottom-right","kind":null,"name":"position"},{"default":0,"kind":null,"name":"_clear"},{"default":[{"background":"#ffc107","icon":{"className":"fas fa-exclamation-triangle","color":"white","tagName":"i"},"type":"warning"},{"background":"#007bff","icon":{"className":"fas fa-info-circle","color":"white","tagName":"i"},"type":"info"}],"kind":null,"name":"types"}]},{"extends":null,"module":null,"name":"Notification","overrides":[],"properties":[{"default":null,"kind":null,"name":"background"},{"default":3000,"kind":null,"name":"duration"},{"default":null,"kind":null,"name":"icon"},{"default":"","kind":null,"name":"message"},{"default":null,"kind":null,"name":"notification_type"},{"default":false,"kind":null,"name":"_destroyed"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"children":[{"id":"1103"},{"id":"1105"}],"margin":[0,0,0,0],"name":"Row01873"},"id":"1102","type":"Row"},{"attributes":{"children":[{"id":"1104"}],"margin":[0,0,0,0],"name":"Column01845"},"id":"1103","type":"Column"},{"attributes":{"margin":[5,5,5,5],"name":"HSpacer01872","sizing_mode":"stretch_width"},"id":"1105","type":"Spacer"},{"attributes":{"client_comm_id":"dcc52dc3d90c4e06965c6713fa44f512","comm_id":"26431736e087445680553680514916fb","plot_id":"1100"},"id":"1108","type":"panel.models.comm_manager.CommManager"},{"attributes":{"children":[{"id":"1107"}],"margin":[0,0,0,0],"name":"Row01850"},"id":"1106","type":"Row"},{"attributes":{"height":480,"margin":[5,5,5,5],"name":"ParamFunction01846","text":"&lt;img src=&quot;data:image/png;base64,...&quot; width=&quot;640px&quot; height=&quot;480px&quot; alt=&quot;&quot;&gt;&lt;/img&gt;","width":640},"id":"1107","type":"panel.models.markup.HTML"},{"attributes":{"children":[{"id":"1101"}],"margin":[0,0,0,0],"name":"Row01875"},"id":"1100","type":"Row"},{"attributes":{"margin":[5,10,5,10],"min_width":200,"options":["amsterdam","athens","barcelona","berlin","budapest","lisbon","london","paris","rome","vienna"],"title":"Select_city","value":"amsterdam","width":200},"id":"1104","type":"panel.models.widgets.CustomSelect"},{"attributes":{"children":[{"id":"1102"},{"id":"1106"}],"margin":[0,0,0,0],"name":"Column01874"},"id":"1101","type":"Column"}],"root_ids":["1100", ...
#     var render_items = [{"docid":"eca5a74f-ad83-4429-9799-7cd38f379ca8","root_ids":["1100"],"roots":{"1100":"22c7dbfd-250f-487e-91be-cf56d4e01ad5"}}];
#     root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#   }
#   if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined && root.Bokeh.Panel !== undefined && (root['Tabulator'] !== undefined)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
#           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ### Template Show will generate a dashboard in the link "http://localhost:54895"

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='Europe airbnb', 
    sidebar=[pn.pane.Markdown("# Europe vacation rentals",style={'font-family': "serif"}), 
             pn.pane.Markdown("### Book unique homes, vacation rentals, and more on Airbnb."), 
             #pn.pane.PNG('file://./airbnb.jpg', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),rate_silder,select_city,select_bedroom,select_room_type
             ],
    main=[pn.Row(pn.Column (RentalTable.panel(width=1200))),
                 #RentalTable.panel(width=500))), 
          pn.Row(pn.Column(Rooms.panel(width=600), margin=(0,25)), 
            pn.Column(bedrooms_bar.panel(width=600), margin=(0,25)))], 
    
                # pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#A01346",
    header_background="#88d8b0",
)
template.show()
#template.servable();
# Out:
# Launching server at http://localhost:59008

# %% [markdown]
# #### Avg listing price in Europe cities

# %%
df_averageprice=airbnb_df.groupby('city')[['realSum']].mean()
df_averageprice
# Out:
#               realSum
# city
# amsterdam  573.112795
# athens     151.744121
# barcelona  293.753706
# berlin     244.583752
# budapest   176.513548
# lisbon     238.210479
# london     362.469256
# paris      392.531403
# rome       205.391950
# vienna     241.582484

# %%
df_averageprice=airbnb_df.groupby(['city','realSum']).mean()
df_averageprice
# Out:
#                         room_shared  room_private  person_capacity  \
# city      realSum
# amsterdam 128.887118            0.0           0.0              2.0
#           143.650552            0.0           1.0              2.0
#           144.822253            0.0           1.0              3.0
#           161.929089            0.0           1.0              2.0
#           165.678532            0.0           1.0              2.0
# ...                             ...           ...              ...
# vienna    881.191127            0.0           0.0              5.0
#           892.410537            0.0           0.0              6.0
#           12942.991375          0.0           0.0              4.0
#           13656.358830          0.0           1.0              2.0
#           13664.305916          0.0           1.0              2.0
#
#                         host_is_superhost  multi  biz  cleanliness_rating  \
# city      realSum
# amsterdam 128.887118                  0.0    1.0  0.0                10.0
#           143.650552                  0.0    0.0  0.0                 8.0
#           144.822253                  0.0    0.0  1.0                 9.0
#           161.929089                  0.0    0.0  0.0                 9.0
#           165.678532                  1.0    0.0  0.0                10.0
# ...                                   ...    ...  ...                 ...
# vienna    881.191127                  0.0    0.0  0.0                10.0
#           892.410537                  0.0    0.0  1.0                 9.0
#           12942.991375                0.0    0.0  1.0                 7.0
#           13656.358830                0.0    0.0  0.0                 9.0
#           13664.305916                0.0    0.0  0.0                 9.0
#
#                         guest_satisfaction_overall  bedrooms      dist  \
# city      realSum
# amsterdam 128.887118                         100.0       1.0  3.914410
#           143.650552                          81.0       1.0  6.502260
#           144.822253                          82.5       1.0  7.579706
#           161.929089                          84.0       1.0  7.145769
#           165.678532                          98.0       1.0  8.787176
# ...                                            ...       ...       ...
# vienna    881.191127                         100.0       2.0  2.770216
#           892.410537                          90.0       3.0  2.385427
#           12942.991375                        93.0       1.0  1.497979
#           13656.358830                        87.0       1.0  2.239486
#           13664.305916                        87.0       1.0  2.239501
#
#                         metro_dist  attr_index  attr_index_norm  rest_index  \
# city      realSum
# amsterdam 128.887118      1.065792  139.266967         7.374278  181.217870
#           143.650552      0.186805   72.665539         3.847689   91.111036
#           144.822253      3.288151   61.176108         3.239316   75.659426
#           161.929089      2.759656   65.630258         3.475166   81.219401
#           165.678532      0.760112   52.680688         2.789477   66.066658
# ...                            ...         ...              ...         ...
# vienna    881.191127      0.305356   87.097295         6.237536  122.202124
#           892.410537      0.167182  109.125612         7.814856  167.288247
#           12942.991375    0.396893  123.776241         8.864325  196.019793
#           13656.358830    0.414409  128.349821         9.191567  201.546533
#           13664.305916    0.414395  128.349070         9.191812  201.545043
#
#                         rest_index_norm       lng        lat
# city      realSum
# amsterdam 128.887118          12.627522   4.84994  52.350000
#           143.650552           6.348748   4.94700  52.325000
#           144.822253           5.272058   4.78573  52.355315
#           161.929089           5.659485   4.79422  52.351760
#           165.678532           4.603620   4.97255  52.311020
# ...                                 ...       ...        ...
# vienna    881.191127           2.921330  16.40627  48.220610
#           892.410537           4.043292  16.34405  48.216820
#           12942.991375         4.685995  16.38614  48.219110
#           13656.358830         4.871302  16.34356  48.207510
#           13664.305916         4.818080  16.34356  48.207510
#
# [10898 rows x 17 columns]

# %%
airbnb_df.groupby(['city']).mean()
# Out:
#               realSum  room_shared  room_private  person_capacity  \
# city
# amsterdam  573.112795     0.004808      0.453846         2.781731
# athens     151.744121     0.002083      0.075189         3.698106
# barcelona  293.753706     0.004236      0.804448         2.616661
# berlin     244.583752     0.029388      0.615539         2.774960
# budapest   176.513548     0.003481      0.104177         3.540776
# lisbon     238.210479     0.012841      0.314246         3.343398
# london     362.469256     0.005004      0.556289         2.846192
# paris      392.531403     0.014055      0.228319         2.953648
# rome       205.391950     0.001329      0.382630         3.357372
# vienna     241.582484     0.004524      0.218830         3.350297
#
#            host_is_superhost     multi       biz  cleanliness_rating  \
# city
# amsterdam           0.284135  0.283173  0.105288            9.465865
# athens              0.428598  0.267424  0.379924            9.638447
# barcelona           0.181433  0.385104  0.325450            9.291564
# berlin              0.257246  0.276167  0.174718            9.461755
# budapest            0.378916  0.303332  0.348831            9.477374
# lisbon              0.213951  0.239459  0.587541            9.370640
# london              0.157410  0.274992  0.387872            9.175023
# paris               0.140700  0.219498  0.245813            9.263606
# rome                0.326687  0.385953  0.334109            9.514678
# vienna              0.284139  0.279050  0.339836            9.472434
#
#            guest_satisfaction_overall  bedrooms      dist  metro_dist  \
# city
# amsterdam                   94.514423  1.292308  2.825052    1.089367
# athens                      95.003598  1.271402  1.803080    0.478656
# barcelona                   91.109072  1.161313  2.116982    0.441248
# berlin                      94.323671  1.070451  5.257093    0.836064
# budapest                    94.585281  1.105669  1.872763    0.544059
# lisbon                      91.093875  1.272428  1.966893    0.711482
# london                      90.645652  1.128790  5.326421    1.005547
# paris                       92.037530  0.972787  2.995823    0.227323
# rome                        93.122300  1.229755  3.026982    0.819794
# vienna                      93.731128  1.102347  3.139488    0.526670
#
#            attr_index  attr_index_norm   rest_index  rest_index_norm  \
# city
# amsterdam  269.064730        14.246499   335.712818        26.097566
# athens     152.312177         5.740839   218.807826         9.954268
# barcelona  460.767010        16.636220   881.070446        19.376528
# berlin     110.223416        16.803111   146.875822        30.666967
# budapest   212.463383        12.675248   423.982306        34.529089
# lisbon     221.970147         7.324730   560.224296        28.274084
# london     295.448532        20.537398   627.541611        11.234105
# paris      374.186582        18.204358   818.768769        42.589111
# rome       470.578123        10.426968  1151.413675        25.078056
# vienna     122.356055         8.762474   176.361199         4.239580
#
#                  lng        lat
# city
# amsterdam   4.890472  52.364637
# athens     23.732031  37.980922
# barcelona   2.169379  41.393495
# berlin     13.399729  52.509110
# budapest   19.061120  47.499287
# lisbon     -9.143792  38.721298
# london     -0.114830  51.503367
# paris       2.343033  48.864343
# rome       12.486139  41.895372
# vienna     16.360856  48.204276

# %%
airbnb_df.realSum.max()
# Out:
# 18545.450284723363

# %%
b =sns.catplot(x="room_type", y="realSum", data=weekends_df)
b

# %%
ratings_df = weekends_df[weekends_df.city.isin(['amsterdam' ,'athens', 'barcelona' ,'berlin' ,'budapest' ,'lisbon', 'london',
 'paris', 'rome', 'vienna'])]
ratings_df.hvplot.hist('guest_satisfaction_overall', by='city', bins=20, bin_range=(-20, 100), height=250,width=250,color= 'ORANGE', subplots=True)
# Out:
# :NdLayout   [city]
#    :Histogram   [guest_satisfaction_overall]   (guest_satisfaction_overall_count)

# %%
plt.scatter(weekends_df['dist'],weekends_df['realSum'],alpha=0.5 ,color ='orange')
#Adding the aesthetics
plt.title('Airbnb price based on distance from city center')
plt.xlabel(' Distance from the city centre')
plt.ylabel('Price based on distance') 
#Show the plot
plt.show()

# %%
plt.scatter(weekends_df['metro_dist'],weekends_df['realSum'],alpha=0.5 ,color ='PINK')
#Adding the aesthetics
plt.title('Airbnb price based on distance from metro center')
plt.xlabel(' Distance from the metro centre')
plt.ylabel('Price based on distance') 
#Show the plot
plt.show()

# %%
weekends_df.groupby(['city','bedrooms']).size()
# Out:
# city       bedrooms
# amsterdam  0             63
#            1            636
#            2            210
#            3             57
#            4              9
#            5              2
# athens     0            213
#            1           1586
#            2            750
#            3             77
#            4              1
# barcelona  0             35
#            1           1113
#            2            109
#            3             19
#            4              1
#            6              1
# berlin     0             86
#            1            990
#            2            102
#            3             20
#            4              1
#            9              1
# budapest   0            297
#            1           1222
#            2            390
#            3             39
# lisbon     0            177
#            1           1961
#            2            640
#            3            116
#            4              7
#            9              4
#            10             1
# london     0            386
#            1           4055
#            2            799
#            3            120
#            4             16
#            5              2
#            8              1
# paris      0            684
#            1           2366
#            2            422
#            3             82
#            4              3
#            5              1
# rome       0            136
#            1           3343
#            2            932
#            3            116
#            4              7
#            5              1
# vienna     0            200
#            1           1253
#            2            302
#            3             40
#            4              4
# dtype: int64

# %%
Unique_city = airbnb_df.groupby('city')['realSum'].mean().sort_values()[::-1].index
Unique_city
# Out:
# Index(['amsterdam', 'paris', 'london', 'barcelona', 'berlin', 'vienna',
#        'lisbon', 'rome', 'budapest', 'athens'],
#       dtype='object', name='city')

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12, 8))
ax = plt.subplot()
plt.axis([0,10,0,1500])
my_pal = {"amestrdam": "g", "setosa": "b", "virginica":"m"}
#sns.set(style="darkgrid")
#sns.set_theme(style='ticks', palette='pastel')
sns.boxplot(x="city", y="realSum", hue="type", palette= 'Blues', 
            data=airbnb_df, fliersize=0.5, linewidth=1, order=Unique_city,notch=True)
plt.ylabel('Total price of Airbnb listing')
ax.set_xticklabels(Unique_city)
plt.grid(axis='y', color='#E8E8E8', linestyle='--', linewidth=.5)
plt.legend(loc=1)
plt.show()
plt.clf()
